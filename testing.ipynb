# %%
import graph_delineator as gd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import graph_delineator as gd
#
# File /nas/cee-water/cjgleason/ted/graph_delineator/src/graph_delineator/__init__.py:1
# ----> 1 from .delin import load_merit_data, load_gauges, WatershedDelineator
#
# File /nas/cee-water/cjgleason/ted/graph_delineator/src/graph_delineator/delin.py:34
#      31 from shapely.ops import unary_union, linemerge
#      32 from typing import Optional
# ---> 34 from .merit_util import load_merit_basin_data, identify_basins_for_gauges
#      35 from .dataclasses import GaugeSplit, DelineationResult
#      36 from .split_catchment import split_catchment_raster
#
# ModuleNotFoundError: No module named 'graph_delineator.merit_util'

# %%
merit_dirs = {
    "catchment": "/nas/cee-ice/data/MERIT-BASINS/pfaf_level_02/",
    "river": "/nas/cee-ice/data/MERIT-BASINS/pfaf_level_02/",
    "flow_dir": "/nas/cee-ice/data/MERIT-Hydro/processed/dir/",
    "accum": "/nas/cee-ice/data/MERIT-Hydro/processed/upg/",
    "megabasins": "/nas/cee-ice/data/MERIT-Hydro/basins_level2/merit_hydro_vect_level2.shp",
}

# %%
merit_data = gd.load_merit_data(
    catchments_file="/nas/cee-ice/data/MERIT-BASINS/pfaf_level_02/",
    rivers_file="/nas/cee-ice/data/MERIT-BASINS/pfaf_level_02/",
)
# Out:
# Loading catchments from /nas/cee-ice/data/MERIT-BASINS/pfaf_level_02/...
# ---------------------------------------------------------------------------
# DataSourceError                           Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 merit_data = gd.load_merit_data(
#       2     catchments_file="/nas/cee-ice/data/MERIT-BASINS/pfaf_level_02/",
#       3     rivers_file="/nas/cee-ice/data/MERIT-BASINS/pfaf_level_02/"
#       4 )
#
# File /nas/cee-water/cjgleason/ted/graph_delineator/src/graph_delineator/delin.py:934, in load_merit_data(catchments_file, rivers_file)
#     923 """
#     924 Load MERIT-Basins data from files.
#     925
#    (...)    931     Dict with 'catchments' and 'rivers' GeoDataFrames
#     932 """
#     933 print(f"Loading catchments from {catchments_file}...")
# --> 934 catchments = gpd.read_file(catchments_file)
#     936 print(f"Loading rivers from {rivers_file}...")
#     937 rivers = gpd.read_file(rivers_file)
#
# ...
